# %%
import pandas as pd

# %%
# File to Load
movies_metadata= "movies_metadata.csv"

# %%
# Read CSV file
read_movies= pd.read_csv(movies_metadata)
# Out:
# /Users/rubyrose/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
read_movies.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
movies= read_movies.drop(columns=["adult","belongs_to_collection", "homepage", "imdb_id", "original_title", 
                                  "runtime", "spoken_languages", "tagline", "poster_path"])

# %%
movies["production_countries"]=
# Out:
# 0    [{'iso_3166_1': 'US', 'name': 'United States o...
# 1    [{'iso_3166_1': 'US', 'name': 'United States o...
# 2    [{'iso_3166_1': 'US', 'name': 'United States o...
# 3    [{'iso_3166_1': 'US', 'name': 'United States o...
# 4    [{'iso_3166_1': 'US', 'name': 'United States o...
# Name: production_countries, dtype: object

# %%
len(movies["production_countries"])
# Out:
# 45466

# %%
movies["production_countries"] == "US"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: production_countries, Length: 45466, dtype: bool

# %%
movies
# Out:
#          budget                                             genres      id  \
# 0      30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2             0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4             0                     [{'id': 35, 'name': 'Comedy'}]   11862
# ...         ...                                                ...     ...
# 45461         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45462         0                      [{'id': 18, 'name': 'Drama'}]  111109
# 45463         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45464         0                                                 []  227506
# 45465         0                                                 []  461257
#
# ...

# %%
movies["production_countries"]
# Out:
# 0        [{'iso_3166_1': 'US', 'name': 'United States o...
# 1        [{'iso_3166_1': 'US', 'name': 'United States o...
# 2        [{'iso_3166_1': 'US', 'name': 'United States o...
# 3        [{'iso_3166_1': 'US', 'name': 'United States o...
# 4        [{'iso_3166_1': 'US', 'name': 'United States o...
#                                ...
# 45461               [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 45462        [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# 45463    [{'iso_3166_1': 'US', 'name': 'United States o...
# 45464             [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 45465     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# Name: production_countries, Length: 45466, dtype: object

# %%
type(movies["production_countries"])
# Out:
# pandas.core.series.Series

# %%
s= pd.Series(["[{'iso_3166_1': 'US', 'name': 'United States of America"])

# %%
sorted_series= s.sort_values()

# %%
sorted_series
# Out:
# 0    [{'iso_3166_1': 'US', 'name': 'United States o...
# dtype: object

# %%
movies["production_countries"]
# Out:
# 0        [{'iso_3166_1': 'US', 'name': 'United States o...
# 1        [{'iso_3166_1': 'US', 'name': 'United States o...
# 2        [{'iso_3166_1': 'US', 'name': 'United States o...
# 3        [{'iso_3166_1': 'US', 'name': 'United States o...
# 4        [{'iso_3166_1': 'US', 'name': 'United States o...
#                                ...
# 45461               [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 45462        [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# 45463    [{'iso_3166_1': 'US', 'name': 'United States o...
# 45464             [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 45465     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# Name: production_countries, Length: 45466, dtype: object

# %%
movies2= movies["production_countries"]

# %%
movies2[pd.Series(movies2 == 'US')]
# Out:
# Series([], Name: production_countries, dtype: object)

# %%
prod_country= movies.groupby(["production_countries", "title"])

# %%
prod_country

# %%
movies[["production_countries", "title"]] == "[{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]"
# Out:
#        production_countries  title
# 0                     False  False
# 1                     False  False
# 2                     False  False
# 3                     False  False
# 4                     False  False
# ...                     ...    ...
# 45461                 False  False
# 45462                 False  False
# 45463                 False  False
# 45464                 False  False
# 45465                  True  False
#
# [45466 rows x 2 columns]
